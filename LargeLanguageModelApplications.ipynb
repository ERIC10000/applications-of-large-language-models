# %% [markdown]
# <a href="https://colab.research.google.com/github/ERIC10000/applications-of-large-language-models/blob/main/LargeLanguageModelApplications.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Large Language Models Applications.
# In this notebook we will explore some applications of Large Language Models using the transformer library
#
# 1. TEXT SUMMARIZATION

# %%
from transformers import pipeline
from warnings import filterwarnings
filterwarnings('ignore')

summarizer = pipeline("summarization")
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.

# %%
text = """ The emergence of artificial intelligence has
reshaped sectors and drastically altered our interaction with
technology. AI-powered solutions are now ubiquitous in
various sectors, including healthcare, finance, and
transportation. These advancements have led to improved
efficiency, accuracy, and innovation. However, concerns
about AI ethics, bias, and job displacement remain. It is
essential to address these challenges while harnessing the
potential of AI for positive societal impact. """

# %%
summary = summarizer(text, max_length=50, min_length=30, do_sample=False)
print(summary[0]['summary_text'])
# Out:
#  The emergence of artificial intelligence has drastically altered our interaction with technology . AI-powered solutions are now ubiquitous in various sectors, including healthcare, finance, and transportation . However, concerns about AI ethics, bias, and job displacement remain .

# %% [markdown]
# 2. TEXT GENERATION

# %%
from transformers import pipeline
from warnings import filterwarnings
filterwarnings('ignore')

generator = pipeline("text-generation")
# Out:
# No model was supplied, defaulted to openai-community/gpt2 and revision 6c0e608 (https://huggingface.co/openai-community/gpt2).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
prompt = "Once upon a time, in a faraway kingdom,"

# %%
generated_text = generator(prompt, max_length=200,
do_sample=True, temperature=0.7)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
print(generated_text[0]['generated_text'])
# Out:
# Once upon a time, in a faraway kingdom, a strange and powerful race of gods, with an evil plan and a dark plan, took over the land of their fathers and took over the world to their own use. They took the land with them, and brought it into the hands of the greatest and most powerful of the gods, and set up an end for them. And now, to the world, the gods have made the world with them, and now the world has set up its end for the gods.
#
# Titania:
#
# They call the gods. So, the gods are the gods; they have created the world. They have done this to create the earth with them.
#
# Titania:
#
# And they have done this to create the heavens with them.
#
# Titania:
#
# And they have done this to create the earth with them.
#
# Titania:
#
# And they have done this to create the earth

# %% [markdown]
# 3. CODE COMPLETION MODELS

# %%
from  transformers import pipeline
from warnings import filterwarnings
filterwarnings('ignore')

# %%
# Load a pre-trained code generation model
# IBM
code_completion = pipeline("text-generation", model="Salesforce/codegen-350M-mono")

# %%
prompt = "def check_leap_year(year):"

# %%
# Complete code snippet
completed_code = code_completion(prompt, max_length=250, num_return_sequences=1)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
# Print the completed code snippet
print(completed_code[0]['generated_text'])
# Out:
# def check_leap_year(year):
#     leap = 0
#     if (year % 4 == 0 and year % 100!= 0) or \
#             year % 400 == 0:
#         leap = 366
#     elif year % 100 == 0:
#         leap = 365
#     return leap
#
# num = int(input('Enter the year'))
# count = int(check_leap_year(num)+1)
#
# i=1
# while i < count:
#     print('{}'.format(num),end=' ')
#     if num%10 == 0 and num%100!= 0 or num%400 == 0:
#         print(count, end=' ')
#     num+=1
#     i+=1

# %%
# BIG TECH COMPANIES HAVE ALSO TRAINED THEIR MODELS WITH HIGH CAPABILITIES USING FINE TUNING
# 1. GOOGLE - GOOGLE GEMINI
# 2. MICROSOFT - OPENAI
# 3. FACEBOOK - ALAMA

# FINE TUNING:
# BULTING A CONVERSATIONAL CHATBOT USING GOOGLE GEMINI
# CREATE AN ACCOUNT WITH GOOGLE GEMINI(API KEY)
